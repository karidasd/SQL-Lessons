# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 9
#
# ### Άσκηση
# Δοκιμάστε να γράψετε κώδικα (όπως στο μάθημα) που να μεταφέρει επιτυχώς 100€ από τον λογαριασμό 2 στον λογαριασμό 1 και στο τέλος να κάνει `commit()`.
