# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 6

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(":memory:")
conn.execute("CREATE TABLE Employees (ID INTEGER, Name TEXT, Salary REAL)")
conn.executemany("INSERT INTO Employees VALUES (?, ?, ?)", [(1, 'Alice', 3000), (2, 'Bob', 4000), (3, 'Charlie', 2000), (4, 'David', 5000)])
conn.commit()

# %% [markdown]
# ### Άσκηση 1
# Χρησιμοποιήστε ένα Subquery για να βρείτε τον/τους υπαλλήλους με τον μεγαλύτερο μισθό.

# %%
# Κώδικας

# %% [markdown]
# ### Άσκηση 2
# Χρησιμοποιήστε `CASE WHEN` για να φτιάξετε μια στήλη `Status` που θα λέει "High" αν ο μισθός είναι πάνω από 3500 και "Low" αν είναι κάτω από 3500.

# %%
# Κώδικας
