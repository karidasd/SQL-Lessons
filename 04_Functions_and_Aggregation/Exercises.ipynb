# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 4

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(":memory:")
conn.execute("CREATE TABLE Orders (ID INTEGER, Region TEXT, Sales REAL)")
conn.executemany("INSERT INTO Orders VALUES (?, ?, ?)", [
    (1, 'North', 500), (2, 'South', 300), (3, 'North', 700), (4, 'East', 400), (5, 'South', 200)
])
conn.commit()

# %% [markdown]
# ### Άσκηση 1
# Βρείτε το συνολικό `Sales` (άθροισμα) για κάθε `Region`. (Χρησιμοποιήστε `GROUP BY`)

# %%
# Κώδικας

# %% [markdown]
# ### Άσκηση 2
# Βρείτε τα `Region` που έχουν συνολικό `Sales` μεγαλύτερο από 600. (Χρησιμοποιήστε `HAVING`)

# %%
# Κώδικας
