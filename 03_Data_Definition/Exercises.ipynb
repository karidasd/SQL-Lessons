# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 3

# %% [markdown]
# ### Άσκηση 1
# Δημιουργήστε έναν πίνακα `Books` με στήλες:
# - `BookID` (ακέραιος, πρωτεύον κλειδί)
# - `Title` (κείμενο, υποχρεωτικό / NOT NULL)
# - `Author` (κείμενο)
# - `Price` (δεκαδικός)

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(":memory:")
# Κώδικας SQL εδώ

# %% [markdown]
# ### Άσκηση 2
# Προσθέστε μια στήλη `PublishedYear` (ακέραιος) στον πίνακα `Books`.

# %%
# Κώδικας SQL εδώ
