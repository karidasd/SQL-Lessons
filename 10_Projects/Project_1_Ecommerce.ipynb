# %% [markdown]
# # 🚀 Ενότητα 10: Mini-Projects
#
# Συγχαρητήρια που φτάσατε ως εδώ! Ήρθε η ώρα να ενώσετε όλα όσα μάθατε (DDL, DML, JOINS, GROUP BY κτλ) σε ένα ολοκληρωμένο Project: **Σύστημα Διαχείρισης Ηλεκτρονικού Καταστήματος (E-commerce System)**.

# %% [markdown]
# ## Προδιαγραφές Project
#
# Θα χρειαστεί να δημιουργήσετε 3 πίνακες:
# 1. `Customers` (CustomerID, Name, Email)
# 2. `Products` (ProductID, ProductName, Price)
# 3. `Orders` (OrderID, CustomerID, ProductID, OrderDate)
#
# ### Βήμα 1: Δημιουργία Πινάκων (DDL)
# Γράψτε τις εντολές `CREATE TABLE` με τα κατάλληλα Primary/Foreign Keys.

# %%
# Γράψτε τον κώδικά σας εδώ

# %% [markdown]
# ### Βήμα 2: Εισαγωγή Δεδομένων (DML)
# Εισάγετε τουλάχιστον 3 πελάτες, 3 προϊόντα και 5 παραγγελίες.

# %%
# Γράψτε τον κώδικά σας εδώ

# %% [markdown]
# ### Βήμα 3: Αναφορές (Queries & Joins)
# Γράψτε ένα ερώτημα που θα εμφανίζει το Όνομα του Πελάτη, το Όνομα του Προϊόντος που αγόρασε και την Ημερομηνία της Παραγγελίας (χρησιμοποιήστε JOIN).

# %%
# Γράψτε τον κώδικά σας εδώ

# %% [markdown]
# ### Βήμα 4: Στατιστικά (Aggregation)
# Γράψτε ένα ερώτημα που να υπολογίζει τα συνολικά έσοδα (Sum of Price) ανά Πελάτη.

# %%
# Γράψτε τον κώδικά σας εδώ
