# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 8

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(":memory:")
conn.execute("CREATE TABLE Products (ID INTEGER, Name TEXT, Price REAL, Category TEXT)")
conn.executemany("INSERT INTO Products VALUES (?, ?, ?, ?)", [(1, 'A', 10, 'Cat1'), (2, 'B', 50, 'Cat1'), (3, 'C', 30, 'Cat2')])
conn.commit()

# %% [markdown]
# ### Άσκηση 1
# Δημιουργήστε μια View με το όνομα `ExpensiveProducts` που να δείχνει μόνο τα προϊόντα με Price > 20.

# %%
# Κώδικας

# %% [markdown]
# ### Άσκηση 2
# Ελέγξτε (κάνοντας ένα SELECT) αν η View `ExpensiveProducts` λειτουργεί σωστά.

# %%
# Κώδικας
