# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 5

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(":memory:")
conn.execute("CREATE TABLE Departments (DeptID INTEGER, DeptName TEXT)")
conn.execute("CREATE TABLE Employees (EmpID INTEGER, EmpName TEXT, DeptID INTEGER)")
conn.executemany("INSERT INTO Departments VALUES (?, ?)", [(1, 'IT'), (2, 'HR'), (3, 'Sales')])
conn.executemany("INSERT INTO Employees VALUES (?, ?, ?)", [(1, 'Alice', 1), (2, 'Bob', 1), (3, 'Charlie', 2)])
conn.commit()

# %% [markdown]
# ### Άσκηση 1
# Κάντε ένα `INNER JOIN` για να βρείτε ποιος υπάλληλος δουλεύει σε ποιο τμήμα (όνομα υπαλλήλου, όνομα τμήματος).

# %%
# Κώδικας

# %% [markdown]
# ### Άσκηση 2
# Κάντε ένα `LEFT JOIN` ξεκινώντας από τα `Departments` για να δείτε όλα τα τμήματα (ακόμα και τα Sales που δεν έχουν υπαλλήλους) και ποιοι δουλεύουν εκεί.

# %%
# Κώδικας
