# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 2
# Τρέξτε το παρακάτω κελί.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(":memory:")
conn.execute("CREATE TABLE Inventory (ID INTEGER PRIMARY KEY AUTOINCREMENT, Item TEXT, Quantity INTEGER)")
conn.executemany("INSERT INTO Inventory (Item, Quantity) VALUES (?, ?)", [
    ("Apples", 50), ("Bananas", 30), ("Oranges", 20)
])
conn.commit()

# %% [markdown]
# ### Άσκηση 1
# Προσθέστε ένα νέο φρούτο, το "Grapes" με ποσότητα 100.

# %%
# Κώδικας

# %% [markdown]
# ### Άσκηση 2
# Ενημερώστε την ποσότητα για τα "Bananas" σε 40.

# %%
# Κώδικας

# %% [markdown]
# ### Άσκηση 3
# Διαγράψτε τα "Oranges" από τον πίνακα.

# %%
# Κώδικας
