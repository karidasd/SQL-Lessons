# %% [markdown]
# # 🏋️ Ασκήσεις: Ενότητα 7

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(":memory:")
conn.execute("CREATE TABLE Sales (Salesperson TEXT, Region TEXT, Amount REAL)")
conn.executemany("INSERT INTO Sales VALUES (?, ?, ?)", [
    ('John', 'North', 500), ('Mike', 'North', 600), ('Anna', 'North', 500),
    ('Chris', 'South', 400), ('Sara', 'South', 700)
])
conn.commit()

# %% [markdown]
# ### Άσκηση 1
# Χρησιμοποιήστε τη συνάρτηση `RANK()` για να βρείτε την κατάταξη κάθε πωλητή (Salesperson) βάσει του ποσού πωλήσεων (Amount) μέσα σε κάθε περιοχή (Region) με φθίνουσα σειρά.

# %%
# Κώδικας
